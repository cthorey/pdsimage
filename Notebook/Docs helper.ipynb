# %%
import os
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
os.chdir('/Users/thorey/Documents/repos/pdsimage/pdsimage')
from Structure import *
from PDS_Extractor import *
imagep = '/Users/thorey/Documents/repos/pdsimage/docs/source/_static'

# %%
ldem = BinaryTable('ldem_16',path_pdsfile = '/Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES')
boundary = ldem.lambert_window(50,-60,120)
wac_image = WacMap(64,*boundary,path_pdsfile = '/Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES')
X,Y,Z = wac_image.image()
fig = plt.figure(figsize = (10,10))
plt.imshow(Z)
fig.savefig(os.path.join(imagep,'test.png'),dpi=50)
# Out:
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES

# %%
region = Area(120,-60,50,path_pdsfile = '/Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES')
region.ppdlola = 64
region.ppdwac = 64
region.overlay(True, os.path.join(imagep,'region.png'))
# Out:
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES

# %%
region.change_window(25)
region.overlay(True, os.path.join(imagep,'region_zoomed_in.png'))
# Out:
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES

# %%
region = Area(120,-60,50,path_pdsfile = '/Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES')
region.ppdlola = 16
region.ppdwac = 16
region.change_window(50)
midlon = (region.window[0]+region.window[1])/2.0
midlat = (region.window[2]+region.window[3])/2.0
profile1 = (midlon,midlon,region.window[2],region.window[3]) #Vertical profile
profile2 = (region.window[0],region.window[1],midlat,midlat) #Horizontal profile
region.draw_profile((profile1,profile2,region.window,), save = True, name = os.path.join(imagep,'region_profile.png'))
# Out:
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# (119.83499379730135, 119.83499379730135, -61.608175706635905, -58.309149089219183)
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# (116.52499802875387, 123.14498956584883, -59.95866239792754, -59.95866239792754)
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# (116.52499802875387, 123.14498956584883, -61.608175706635905, -58.309149089219183)
# No overlap - Processing should be quick
# ...

# %%
Copernicus =Crater('name','Copernicus',path_pdsfile = '/Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES')

# %%
Copernicus.ppdlola = 64
Copernicus.ppdwac = 64
Copernicus.overlay(True, os.path.join(imagep,'Copernicus.png'))
# Out:
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES

# %%
M13 = Dome('name','M13',path_pdsfile = '/Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES')
M13.ppdlola = 64
M13.ppdwac = 64
M13.overlay(True, os.path.join(imagep,'M13.png'))
# Out:
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
# No overlap - Processing should be quick
# PDS FILES used are in: /Users/thorey/Documents/These/Projet/FFC/pdsimage/pdsimage/PDS_FILES
